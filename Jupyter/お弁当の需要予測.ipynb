# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression as LR

# 作業ディレクトリ指定
import os
os.chdir("D:\Study\SIGNATE\お弁当需要予測")

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
test.head(10) # 先頭5行表示
# Out:
#      datetime week  soldout          name   kcal       remarks          event  \
# 0   2014-10-1    水        1         メンチカツ  420.0           NaN            NaN
# 1   2014-10-2    木        0     バーベキューチキン  415.0           NaN            NaN
# 2   2014-10-3    金        0    豚肉のマスタード焼き  405.0           NaN            NaN
# 3   2014-10-6    月        1          麻婆春雨  400.0           NaN            NaN
# 4   2014-10-7    火        0      厚揚げ肉みそ炒め  430.0           NaN            NaN
# 5   2014-10-8    水        0  完熟トマトのホットカレー  420.0           NaN            NaN
# 6   2014-10-9    木        0        豚キムチ炒め  435.0           NaN  キャリアアップ支援セミナー
# 7  2014-10-10    金        0        ポークカレー    NaN      お楽しみメニュー            NaN
# 8  2014-10-14    火        0       若鶏梅肉包揚げ  408.0           NaN            NaN
# 9  2014-10-15    水        1       ミックスグリル  450.0  料理長のこだわりメニュー            NaN
#
#    payday weather precipitation  temperature
# 0     NaN       雨             0         20.2
# 1     NaN       曇            --         23.9
# 2     NaN      晴れ            --         28.7
# 3     NaN       雨           0.5         21.5
# 4     NaN      晴れ            --         22.1
# 5     NaN      晴れ            --         23.3
# 6     NaN       曇            --         22.5
# 7     1.0      薄曇            --         26.1
# 8     NaN      快晴            --         26.8
# 9     NaN       雨           1.5         15.6

# %%
test.tail(10) # 最後尾5行表示
# Out:
#       datetime week  soldout            name   kcal       remarks event  \
# 30  2014-11-14    金        1      エビフライ・エビカツ  427.0           NaN   NaN
# 31  2014-11-17    月        1      野菜ごろごろシチュー  433.0           NaN   NaN
# 32  2014-11-18    火        1            麻婆豆腐  409.0           NaN   NaN
# 33  2014-11-19    水        0  ベルギー風チキンのクリーム煮  430.0  料理長のこだわりメニュー   NaN
# 34  2014-11-20    木        1          スタミナ炒め  421.0           NaN   NaN
# 35  2014-11-21    金        0           ロコモコ丼    NaN      お楽しみメニュー   NaN
# 36  2014-11-25    火        1     なすと挽肉のはさみ揚げ  460.0           NaN   NaN
# 37  2014-11-26    水        1         鶏肉の治部煮風  415.0           NaN   NaN
# 38  2014-11-27    木        0             牛丼風  420.0           NaN   NaN
# 39  2014-11-28    金        0    鶏肉のスイートチリソース  416.0           NaN   NaN
#
#     payday weather precipitation  temperature
# 30     NaN      快晴            --         15.8
# 31     NaN      薄曇            --         14.3
# 32     NaN      快晴            --         16.1
# 33     NaN      快晴            --         14.9
# 34     NaN       曇            --         10.5
# 35     NaN      快晴            --         14.9
# 36     NaN       雨           1.5         11.4
# 37     NaN       雨             1          9.2
# 38     NaN      快晴            --         15.1
# 39     NaN       曇            --         15.3

# %%
test.shape # 行数と列数
# Out:
# (40, 11)

# %%
trainX = train["temperature"]
y = train["y"]

# %%
testX = test["temperature"]

# %%
trainX = trainX.values.reshape(-1,1)
testX = testX.values.reshape(-1,1)

# %%
model1 = LR()

# %%
model1.fit(trainX,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model1.coef_
# Out:
# array([-2.5023821])

# %%
model1.intercept_
# Out:
# 134.79948383749922

# %%
pred = model1.predict(testX)
