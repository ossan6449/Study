# %% [markdown]
# # PART4 欠損値を確認してみよう

# %% [markdown]
# ## おまじない

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## データの読み込み
# - train.csvを読み込みましょう
# - 読み込んだものは変数trainに代入しましょう

# %%
train = pd.read_csv("E:/til/Jupyter/SIGNATE/bento/train.csv")

# %% [markdown]
# ## trainの先頭行を確認しましょう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## 各値が欠損値か否かを出力しましょう
# - 欠損とは何らかの理由で、データの値が入っていない状態のことをいいます
# - データ分析において欠損がある場合の対応はとても重要となります
# - 欠損の有無を確認する為にはisnull関数を使います
# - 欠損値の時、Trueと表示されます

# %%
train.isnull()
# Out:
#      datetime      y   week  soldout   name   kcal  remarks  event  payday  \
# 0       False  False  False    False  False   True     True   True    True
# 1       False  False  False    False  False   True     True   True    True
# 2       False  False  False    False  False   True     True   True    True
# 3       False  False  False    False  False   True     True   True    True
# 4       False  False  False    False  False   True     True   True    True
# 5       False  False  False    False  False   True     True   True    True
# 6       False  False  False    False  False   True     True   True    True
# 7       False  False  False    False  False   True     True   True    True
# 8       False  False  False    False  False   True     True   True    True
# 9       False  False  False    False  False   True     True   True    True
# 10      False  False  False    False  False   True     True   True    True
# 11      False  False  False    False  False   True     True   True    True
# 12      False  False  False    False  False   True     True   True    True
# 13      False  False  False    False  False   True     True   True    True
# 14      False  False  False    False  False   True     True   True    True
# 15      False  False  False    False  False   True     True   True    True
# 16      False  False  False    False  False   True     True   True   False
# 17      False  False  False    False  False   True     True   True    True
# 18      False  False  False    False  False   True     True   True    True
# 19      False  False  False    False  False   True     True   True    True
# 20      False  False  False    False  False   True     True   True    True
# 21      False  False  False    False  False   True     True  False    True
# 22      False  False  False    False  False   True     True   True    True
# 23      False  False  False    False  False   True     True   True    True
# 24      False  False  False    False  False   True     True   True    True
# 25      False  False  False    False  False   True     True   True    True
# 26      False  False  False    False  False   True     True   True    True
# 27      False  False  False    False  False   True     True   True    True
# 28      False  False  False    False  False  False     True   True    True
# 29      False  False  False    False  False  False     True   True    True
# ..        ...    ...    ...      ...    ...    ...      ...    ...     ...
# 177     False  False  False    False  False  False     True   True    True
# 178     False  False  False    False  False  False     True   True    True
# 179     False  False  False    False  False  False    False  False    True
# 180     False  False  False    False  False  False     True  False    True
# 181     False  False  False    False  False   True    False   True    True
# 182     False  False  False    False  False  False     True   True    True
# 183     False  False  False    False  False  False     True   True    True
# 184     False  False  False    False  False  False     True   True    True
# 185     False  False  False    False  False  False     True   True    True
# 186     False  False  False    False  False  False     True   True    True
# 187     False  False  False    False  False  False     True   True    True
# 188     False  False  False    False  False  False    False   True    True
# 189     False  False  False    False  False  False     True   True    True
# 190     False  False  False    False  False  False     True   True    True
# 191     False  False  False    False  False  False     True   True    True
# 192     False  False  False    False  False  False     True   True    True
# 193     False  False  False    False  False  False     True   True    True
# 194     False  False  False    False  False  False     True   True   False
# 195     False  False  False    False  False  False     True   True    True
# 196     False  False  False    False  False   True    False   True    True
# 197     False  False  False    False  False  False     True   True    True
# 198     False  False  False    False  False  False    False  False    True
# 199     False  False  False    False  False  False     True   True    True
# 200     False  False  False    False  False  False     True   True    True
# 201     False  False  False    False  False  False     True   True    True
# 202     False  False  False    False  False  False     True   True    True
# 203     False  False  False    False  False  False     True   True    True
# 204     False  False  False    False  False   True    False  False    True
# 205     False  False  False    False  False  False     True   True    True
# 206     False  False  False    False  False  False     True   True    True
#
#      weather  precipitation  temperature
# 0      False          False        False
# 1      False          False        False
# 2      False          False        False
# 3      False          False        False
# 4      False          False        False
# 5      False          False        False
# 6      False          False        False
# 7      False          False        False
# 8      False          False        False
# 9      False          False        False
# 10     False          False        False
# 11     False          False        False
# 12     False          False        False
# 13     False          False        False
# 14     False          False        False
# 15     False          False        False
# 16     False          False        False
# 17     False          False        False
# 18     False          False        False
# 19     False          False        False
# 20     False          False        False
# 21     False          False        False
# 22     False          False        False
# 23     False          False        False
# 24     False          False        False
# 25     False          False        False
# 26     False          False        False
# 27     False          False        False
# 28     False          False        False
# 29     False          False        False
# ..       ...            ...          ...
# 177    False          False        False
# 178    False          False        False
# 179    False          False        False
# 180    False          False        False
# 181    False          False        False
# 182    False          False        False
# 183    False          False        False
# 184    False          False        False
# 185    False          False        False
# 186    False          False        False
# 187    False          False        False
# 188    False          False        False
# 189    False          False        False
# 190    False          False        False
# 191    False          False        False
# 192    False          False        False
# 193    False          False        False
# 194    False          False        False
# 195    False          False        False
# 196    False          False        False
# 197    False          False        False
# 198    False          False        False
# 199    False          False        False
# 200    False          False        False
# 201    False          False        False
# 202    False          False        False
# 203    False          False        False
# 204    False          False        False
# 205    False          False        False
# 206    False          False        False
#
# [207 rows x 12 columns]

# %% [markdown]
# ## 各列（カラム）にTrueが１つ以上あるかないかを確かめてみましょう
# - isnull関数のあとにany関数を付け加えます。付け加える時はドット(.)で繋ぎます
# - 1つ以上欠損値を含んでいる場合、Trueと表示されます

# %%
train.isnull().any()
# Out:
# datetime         False
# y                False
# week             False
# soldout          False
# name             False
# kcal              True
# remarks           True
# event             True
# payday            True
# weather          False
# precipitation    False
# temperature      False
# dtype: bool

# %% [markdown]
# ## 具体的に各列（カラム）に欠損値が幾つあるか数えてみましょう
# - isnull関数のあとにsum関数を付け加えます

# %%
train.isnull().sum()
# Out:
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# dtype: int64

# %% [markdown]
# ## もう一度trainの先頭行を出力し、kcalに注目してみましょう

# %%
train.head().isnull()
# Out:
#    datetime      y   week  soldout   name  kcal  remarks  event  payday  \
# 0     False  False  False    False  False  True     True   True    True
# 1     False  False  False    False  False  True     True   True    True
# 2     False  False  False    False  False  True     True   True    True
# 3     False  False  False    False  False  True     True   True    True
# 4     False  False  False    False  False  True     True   True    True
#
#    weather  precipitation  temperature
# 0    False          False        False
# 1    False          False        False
# 2    False          False        False
# 3    False          False        False
# 4    False          False        False

# %% [markdown]
# ## 欠損値の処理をしましょう
# - 欠損値の処理は別のなんらかの値を代入（補間といいます）するか、欠損値を含む行を削除するかで対応します
# - ここではまず、欠損値を0で補間してみましょう
# - fillna関数を使います

# %%
train.fillna(0)
# Out:
#        datetime    y week  soldout            name   kcal          remarks  \
# 0    2013-11-18   90    月        0        厚切りイカフライ    0.0                0
# 1    2013-11-19  101    火        1         手作りヒレカツ    0.0                0
# 2    2013-11-20  118    水        0      白身魚唐揚げ野菜あん    0.0                0
# 3    2013-11-21  120    木        1          若鶏ピリ辛焼    0.0                0
# 4    2013-11-22  130    金        1        ビッグメンチカツ    0.0                0
# 5    2013-11-25  135    月        1            鶏の唐揚    0.0                0
# 6    2013-11-26  145    火        0        豚のスタミナ炒め    0.0                0
# 7    2013-11-27  140    水        1        ボローニャ風カツ    0.0                0
# 8    2013-11-28  151    木        0           ハンバーグ    0.0                0
# 9    2013-11-29  116    金        0   タルタルinソーセージカツ    0.0                0
# 10    2013-12-2  151    月        1           マーボ豆腐    0.0                0
# 11    2013-12-3  153    火        1        厚揚げ豚生姜炒め    0.0                0
# 12    2013-12-4  151    水        1    クリームチーズ入りメンチ    0.0                0
# 13    2013-12-5  171    木        0     鶏のカッシュナッツ炒め    0.0                0
# 14    2013-12-6  134    金        0        手作りロースカツ    0.0                0
# 15    2013-12-9  165    月        1      ハンバーグデミソース    0.0                0
# 16   2013-12-10  155    火        0   やわらかロースのサムジョン    0.0                0
# 17   2013-12-11  157    水        0            五目御飯    0.0                0
# 18   2013-12-12  109    木        0            肉じゃが    0.0                0
# 19   2013-12-13  111    金        1        タンドリーチキン    0.0                0
# 20   2013-12-16  160    月        0       カキフライタルタル    0.0                0
# 21   2013-12-17  145    火        0         手作りヒレカツ    0.0                0
# 22   2013-12-18  145    水        1             回鍋肉    0.0                0
# 23   2013-12-19  151    木        0         ポーク味噌焼き    0.0                0
# 24   2013-12-20  134    金        1       鶏の唐揚げ甘酢あん    0.0                0
# 25   2013-12-24  122    火        0       さっくりメンチカツ    0.0                0
# 26   2013-12-25  121    水        1       手ごね風ハンバーグ    0.0                0
# 27   2013-12-26   80    木        0              酢豚    0.0                0
# 28     2014-1-7  131    火        0    カレー入りソーセージカツ  404.0                0
# 29     2014-1-8  128    水        0          豚肉の生姜焼  462.0                0
# ..          ...  ...  ...      ...             ...    ...              ...
# 177   2014-8-18   56    月        0     洋食屋さんのメンチカツ  396.0                0
# 178   2014-8-19   53    火        1           牛スキヤキ  385.0                0
# 179   2014-8-20   56    水        0   豚ロースのピザ風チーズ焼き  423.0     料理長のこだわりメニュー
# 180   2014-8-21   54    木        0           チキン南蛮  405.0                0
# 181   2014-8-22  100    金        1           ロコモコ丼    0.0         お楽しみメニュー
# 182   2014-8-25   55    月        0        白身魚の南部焼き  412.0                0
# 183   2014-8-26   68    火        0          キーマカレー  400.0                0
# 184   2014-8-27   62    水        0         カレイの唐揚げ  410.0                0
# 185   2014-8-28   56    木        0        豚肉の胡麻シャブ  396.0                0
# 186   2014-8-29   39    金        0       チキンの辛味噌焼き  398.0                0
# 187    2014-9-1   65    月        1         ビーフシチュー  380.0                0
# 188    2014-9-2   68    火        1         名古屋味噌カツ  440.0            手作りの味
# 189    2014-9-3   53    水        0             親子煮  408.0                0
# 190    2014-9-4   54    木        1  チキンステーキ・きのこソース  405.0                0
# 191    2014-9-5   43    金        0           メンチカツ  380.0                0
# 192    2014-9-8   68    月        1         鶏肉の山賊焼き  385.0                0
# 193    2014-9-9   63    火        0      ハンバーグデミソース  460.0                0
# 194   2014-9-10   54    水        0     ぶりレモンペッパー焼き  450.0                0
# 195   2014-9-11   53    木        0        手作りチキンカツ  385.0                0
# 196   2014-9-12  115    金        0          ポークカレー    0.0         お楽しみメニュー
# 197   2014-9-16   56    火        0        チーズメンチカツ  438.0                0
# 198   2014-9-17   49    水        0        チキンフリカッセ  430.0     料理長のこだわりメニュー
# 199   2014-9-18   46    木        0     カレイ唐揚げ 甘酢あん  395.0                0
# 200   2014-9-19   45    金        0         厚切イカフライ  400.0                0
# 201   2014-9-22   29    月        0             筑前煮  395.0                0
# 202   2014-9-24   59    水        1     白身魚のマスタード焼き  408.0                0
# 203   2014-9-25   50    木        0         牛カルビ焼き肉  394.0                0
# 204   2014-9-26   45    金        0        ランチビュッフェ    0.0  スペシャルメニュー（800円）
# 205   2014-9-29   56    月        1        豚肉と玉子の炒め  404.0                0
# 206   2014-9-30   40    火        0    鶏肉とカシューナッツ炒め  398.0                0
#
#              event  payday weather precipitation  temperature
# 0                0     0.0      快晴            --         19.8
# 1                0     0.0      快晴            --         17.0
# 2                0     0.0      快晴            --         15.5
# 3                0     0.0      快晴            --         15.2
# 4                0     0.0      快晴            --         16.1
# 5                0     0.0       曇            --         14.6
# 6                0     0.0      快晴            --         17.9
# 7                0     0.0      晴れ            --         14.7
# 8                0     0.0      薄曇            --         17.7
# 9                0     0.0      快晴            --         12.1
# 10               0     0.0      快晴            --         13.8
# 11               0     0.0      快晴            --         13.9
# 12               0     0.0      晴れ            --         13.5
# 13               0     0.0      快晴            --         13.8
# 14               0     0.0      快晴            --         14.9
# 15               0     0.0       曇            --          9.1
# 16               0     1.0       曇           0.5          7.1
# 17               0     0.0       曇            --         11.0
# 18               0     0.0      快晴            --         12.3
# 19               0     0.0      快晴            --         13.9
# 20               0     0.0      快晴            --         11.3
# 21            ママの会     0.0       曇            --         10.8
# 22               0     0.0       曇            --          7.8
# 23               0     0.0       雨           0.5          6.8
# 24               0     0.0       曇            --          8.4
# 25               0     0.0      快晴            --         11.5
# 26               0     0.0      快晴            --          8.0
# 27               0     0.0       曇            --          7.3
# 28               0     0.0      快晴            --          7.3
# 29               0     0.0       曇            --          9.8
# ..             ...     ...     ...           ...          ...
# 177              0     0.0       曇            --         32.2
# 178              0     0.0      晴れ            --         33.3
# 179           ママの会     0.0      快晴            --         33.3
# 180  キャリアアップ支援セミナー     0.0      薄曇            --         33.0
# 181              0     0.0      晴れ            --         33.1
# 182              0     0.0       曇             0         26.0
# 183              0     0.0       雨             0         26.2
# 184              0     0.0       曇             0         21.0
# 185              0     0.0       雨             0         21.6
# 186              0     0.0       曇             0         25.1
# 187              0     0.0       曇            --         23.4
# 188              0     0.0      晴れ            --         29.1
# 189              0     0.0       曇            --         26.7
# 190              0     0.0       曇             0         26.5
# 191              0     0.0      晴れ            --         30.2
# 192              0     0.0       曇            --         23.1
# 193              0     0.0      晴れ            --         26.8
# 194              0     1.0       曇             0         25.0
# 195              0     0.0       曇            --         21.9
# 196              0     0.0      晴れ            --         27.3
# 197              0     0.0      晴れ            --         28.8
# 198           ママの会     0.0       曇            --         25.0
# 199              0     0.0       曇            --         24.1
# 200              0     0.0      薄曇            --         23.6
# 201              0     0.0      晴れ            --         25.2
# 202              0     0.0       曇             0         24.8
# 203              0     0.0       曇             0         25.4
# 204  キャリアアップ支援セミナー     0.0      晴れ            --         27.1
# 205              0     0.0      快晴            --         26.6
# 206              0     0.0      快晴            --         28.1
#
# [207 rows x 12 columns]

# %% [markdown]
# ## 今度は欠損値を削除してみましょう
# - dropna関数を使います
# - ある列に欠損値があった場合のみ、その行を削除したい場合はオプションとしてsubset=[ ]を使います

# %%
train.dropna()
# Out:
# Empty DataFrame
# Columns: [datetime, y, week, soldout, name, kcal, remarks, event, payday, weather, precipitation, temperature]
# Index: []

# %%
train.dropna(subset=["kcal"])
# Out:
#       datetime    y week  soldout             name   kcal  \
# 28    2014-1-7  131    火        0     カレー入りソーセージカツ  404.0
# 29    2014-1-8  128    水        0           豚肉の生姜焼  462.0
# 30    2014-1-9  129    木        1           鶏チリソース  435.0
# 31   2014-1-10   87    金        0         手作りロースカツ  440.0
# 32   2014-1-14  129    火        1      鶏の照り焼きマスタード  376.0
# 33   2014-1-15  134    水        0           さんま辛味焼  450.0
# 34   2014-1-16  107    木        0     カレイ唐揚げ野菜あんかけ  415.0
# 35   2014-1-17   85    金        1              回鍋肉  430.0
# 36   2014-1-20  126    月        1       ジューシーメンチカツ  375.0
# 37   2014-1-21  129    火        1          サバ焼味噌掛け  447.0
# 38   2014-1-22  126    水        1      手作りひれかつとカレー  426.0
# 39   2014-1-23  107    木        0               酢豚  400.0
# 40   2014-1-24   92    金        1  鶏のレモンペッパー焼orカレー  418.0
# 41   2014-1-27  126    月        1         チンジャオロース  415.0
# 42   2014-1-28  120    火        0        海老フライタルタル  445.0
# 43   2014-1-29  121    水        1       チーズ入りメンチカツ  450.0
# 44   2014-1-30  105    木        1            鶏の唐揚げ  448.0
# 45   2014-1-31   92    金        1           メダイ照り焼  460.0
# 46    2014-2-3  139    月        1      ハンバーグカレーソース  445.0
# 47    2014-2-4  121    火        1         さわら焼味噌掛け  430.0
# 48    2014-2-5  126    水        1          鶏のピリ辛焼き  420.0
# 49    2014-2-6  111    木        1         手作りロースカツ  435.0
# 50    2014-2-7   91    金        1      ホタテクリ―ムシチュー  425.0
# 51   2014-2-10  137    月        0      鶏の唐揚げおろしソース  423.0
# 52   2014-2-12  111    水        0      ますのマスタードソース  415.0
# 53   2014-2-13   84    木        0              回鍋肉  438.0
# 54   2014-2-14   86    金        1         ロース甘味噌焼き  432.0
# 55   2014-2-17  137    月        1         チンジャオロース  416.0
# 56   2014-2-18   99    火        0     海老フライとホタテ串カツ  426.0
# 57   2014-2-19  113    水        0    ハンバーグ和風きのこソース  405.0
# ..         ...  ...  ...      ...              ...    ...
# 173   2014-8-7   63    木        0  チキン香草焼きマスタードソース  415.0
# 175  2014-8-11   45    月        0     サーモンフライ・タルタル  411.0
# 176  2014-8-12   40    火        1           厚切ハムカツ  400.0
# 177  2014-8-18   56    月        0      洋食屋さんのメンチカツ  396.0
# 178  2014-8-19   53    火        1            牛スキヤキ  385.0
# 179  2014-8-20   56    水        0    豚ロースのピザ風チーズ焼き  423.0
# 180  2014-8-21   54    木        0            チキン南蛮  405.0
# 182  2014-8-25   55    月        0         白身魚の南部焼き  412.0
# 183  2014-8-26   68    火        0           キーマカレー  400.0
# 184  2014-8-27   62    水        0          カレイの唐揚げ  410.0
# 185  2014-8-28   56    木        0         豚肉の胡麻シャブ  396.0
# 186  2014-8-29   39    金        0        チキンの辛味噌焼き  398.0
# 187   2014-9-1   65    月        1          ビーフシチュー  380.0
# 188   2014-9-2   68    火        1          名古屋味噌カツ  440.0
# 189   2014-9-3   53    水        0              親子煮  408.0
# 190   2014-9-4   54    木        1   チキンステーキ・きのこソース  405.0
# 191   2014-9-5   43    金        0            メンチカツ  380.0
# 192   2014-9-8   68    月        1          鶏肉の山賊焼き  385.0
# 193   2014-9-9   63    火        0       ハンバーグデミソース  460.0
# 194  2014-9-10   54    水        0      ぶりレモンペッパー焼き  450.0
# 195  2014-9-11   53    木        0         手作りチキンカツ  385.0
# 197  2014-9-16   56    火        0         チーズメンチカツ  438.0
# 198  2014-9-17   49    水        0         チキンフリカッセ  430.0
# 199  2014-9-18   46    木        0      カレイ唐揚げ 甘酢あん  395.0
# 200  2014-9-19   45    金        0          厚切イカフライ  400.0
# 201  2014-9-22   29    月        0              筑前煮  395.0
# 202  2014-9-24   59    水        1      白身魚のマスタード焼き  408.0
# 203  2014-9-25   50    木        0          牛カルビ焼き肉  394.0
# 205  2014-9-29   56    月        1         豚肉と玉子の炒め  404.0
# 206  2014-9-30   40    火        0     鶏肉とカシューナッツ炒め  398.0
#
#                       remarks          event  payday weather precipitation  \
# 28                        NaN            NaN     NaN      快晴            --
# 29                        NaN            NaN     NaN       曇            --
# 30                        NaN            NaN     NaN       曇            --
# 31                        NaN            NaN     1.0      快晴            --
# 32                        NaN            NaN     NaN      晴れ            --
# 33                        NaN            NaN     NaN       曇            --
# 34                        NaN            NaN     NaN      快晴            --
# 35                        NaN           ママの会     NaN      快晴            --
# 36                        NaN            NaN     NaN      晴れ            --
# 37                        NaN            NaN     NaN      快晴            --
# 38                        NaN            NaN     NaN      快晴            --
# 39                        NaN            NaN     NaN      快晴            --
# 40   鶏のレモンペッパー焼（50食）、カレー（42食）            NaN     NaN      快晴            --
# 41                        NaN            NaN     NaN      快晴            --
# 42                        NaN            NaN     NaN      快晴            --
# 43                        NaN            NaN     NaN      快晴            --
# 44                        NaN            NaN     NaN       曇            --
# 45                        NaN            NaN     NaN      快晴            --
# 46                        NaN            NaN     NaN      晴れ            --
# 47                        NaN            NaN     NaN       雨             0
# 48                        NaN            NaN     NaN      快晴            --
# 49                        NaN            NaN     NaN       曇            --
# 50                        NaN            NaN     NaN      晴れ            --
# 51                        NaN            NaN     1.0       曇            --
# 52                        NaN            NaN     NaN       曇            --
# 53                        NaN            NaN     NaN       曇            --
# 54                        NaN            NaN     NaN       雪           0.5
# 55                        NaN            NaN     NaN      晴れ            --
# 56                        NaN            NaN     NaN      晴れ            --
# 57                        NaN            NaN     NaN      薄曇            --
# ..                        ...            ...     ...     ...           ...
# 173                       NaN            NaN     NaN      晴れ            --
# 175                       NaN            NaN     NaN      晴れ            --
# 176                       NaN            NaN     NaN       雨             0
# 177                       NaN            NaN     NaN       曇            --
# 178                       NaN            NaN     NaN      晴れ            --
# 179              料理長のこだわりメニュー           ママの会     NaN      快晴            --
# 180                       NaN  キャリアアップ支援セミナー     NaN      薄曇            --
# 182                       NaN            NaN     NaN       曇             0
# 183                       NaN            NaN     NaN       雨             0
# 184                       NaN            NaN     NaN       曇             0
# 185                       NaN            NaN     NaN       雨             0
# 186                       NaN            NaN     NaN       曇             0
# 187                       NaN            NaN     NaN       曇            --
# 188                     手作りの味            NaN     NaN      晴れ            --
# 189                       NaN            NaN     NaN       曇            --
# 190                       NaN            NaN     NaN       曇             0
# 191                       NaN            NaN     NaN      晴れ            --
# 192                       NaN            NaN     NaN       曇            --
# 193                       NaN            NaN     NaN      晴れ            --
# 194                       NaN            NaN     1.0       曇             0
# 195                       NaN            NaN     NaN       曇            --
# 197                       NaN            NaN     NaN      晴れ            --
# 198              料理長のこだわりメニュー           ママの会     NaN       曇            --
# 199                       NaN            NaN     NaN       曇            --
# 200                       NaN            NaN     NaN      薄曇            --
# 201                       NaN            NaN     NaN      晴れ            --
# 202                       NaN            NaN     NaN       曇             0
# 203                       NaN            NaN     NaN       曇             0
# 205                       NaN            NaN     NaN      快晴            --
# 206                       NaN            NaN     NaN      快晴            --
#
#      temperature
# 28           7.3
# 29           9.8
# 30          10.9
# 31           5.1
# 32           5.8
# 33           2.9
# 34           7.0
# 35           7.8
# 36           6.5
# 37          10.4
# 38           7.4
# 39           8.5
# 40          10.1
# 41           5.1
# 42          12.6
# 43          10.3
# 44          15.3
# 45          14.1
# 46          15.9
# 47           3.8
# 48           3.0
# 49           4.2
# 50           5.5
# 51           7.8
# 52           6.3
# 53           6.4
# 54           1.2
# 55          11.6
# 56           6.8
# 57           7.3
# ..           ...
# 173         32.1
# 175         32.4
# 176         29.4
# 177         32.2
# 178         33.3
# 179         33.3
# 180         33.0
# 182         26.0
# 183         26.2
# 184         21.0
# 185         21.6
# 186         25.1
# 187         23.4
# 188         29.1
# 189         26.7
# 190         26.5
# 191         30.2
# 192         23.1
# 193         26.8
# 194         25.0
# 195         21.9
# 197         28.8
# 198         25.0
# 199         24.1
# 200         23.6
# 201         25.2
# 202         24.8
# 203         25.4
# 205         26.6
# 206         28.1
#
# [166 rows x 12 columns]

# %% [markdown]
# ## precipitationには本当に欠損値がないか確認してみましょう
# - 行の中の値がそれぞれ幾つあるかを確認したい場合は、value_counts関数を使います

# %%
train["precipitation"].value_counts()
# Out:
# --     169
# 0       23
# 0.5      9
# 1.5      2
# 2.5      1
# 6        1
# 6.5      1
# 1        1
# Name: precipitation, dtype: int64
